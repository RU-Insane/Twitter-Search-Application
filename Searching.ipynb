# %%
import time
import pymongo
import psycopg2
import pandas as pd
from cache import SearchCache

# %%
class SearchEngine:
    def __init__(self, db_type, cache_size=100, cache_ttl=3600):
        """
        Initializes a SearchEngine object with a specified database type and cache settings.

        Args:
        - db_type (str): Either "mongodb" or "postgresql"
        - cache_size (int): Maximum number of items to store in cache
        - cache_ttl (int): Time-to-live (in seconds) for cached items
        """
        # initialize the search engine with a database type and cache size/ttl values
        self.db_type = db_type
        # initialize a cache object for the search engine using the SearchCache class
        self.cache = SearchCache(cache_size, cache_ttl)
        # establish a database connection based on the given database type
        if self.db_type == 'mongodb':
            self.db_client = pymongo.MongoClient('mongodb+srv://<user>:<password>@cluster0.wkyhu.mongodb.net/?retryWrites=true&w=majority')
            self.tweets_collection = self.db_client['twitter_db']['tweets_data']
        elif self.db_type == 'postgresql':
            self.db_conn = psycopg2.connect(database="postgres", user="postgres", password="", host="localhost")
            self.users_cursor = self.db_conn.cursor()
        else:
            # raise a ValueError if an invalid database type is given
            raise ValueError('Invalid database type')

    
    def most_engaging_tweets(self, n=10):
        """
        Returns the most engaging n tweets in the database, where engagement is defined as the sum of retweet
        count, reply count, and favorite count.

        Args:
        - n (int): Number of tweets to return.

        Returns:
        - list: List of the top n tweets, each represented as a dictionary.
        """
        if 'most_engaging_tweets' in self.cache:
            print("Retrieving 'most engaging tweets' from cache!")
            return self.cache['most_engaging_tweets']

        pipeline = [
            {
                '$project': {
                    '_id': 0,
                    'tweet_id': 1,
                    'user': 1,
                    'name': 1,
                    'date': 1,
                    'text': 1,
                    'retweet': {
                        '$cond': {
                            'if': { '$eq': ['$is_retweet', True] },
                            'then': '$retweet',
                            'else': None
                        }
                    },
                    'quote': {
                        '$cond': {
                            'if': { '$eq': ['$is_quote', True] },
                            'then': '$quote',
                            'else': None
                        }
                    },
                    'retweet_count': {
                        '$sum': {
                            '$cond': [
                                { '$eq': ['$quote', None] },
                                {
                                    '$cond': [
                                        { '$eq': ['$retweet', None] },
                                        '$retweet_count',
                                        '$retweet.retweet_count'
                                    ]
                                },
                                '$quote.retweet_count'
                            ]
                        }
                    },
                    'reply_count': {
                        '$sum': {
                            '$cond': [
                                { '$eq': ['$quote', None] },
                                {
                                    '$cond': [
                                        { '$eq': ['$retweet', None] },
                                        '$reply_count',
                                        '$retweet.reply_count'
                                    ]
                                },
                                '$quote.reply_count'
                            ]
                        }
                    },
                    'favorite_count': {
                        '$sum': {
                            '$cond': [
                                { '$eq': ['$quote', None] },
                                {
                                    '$cond': [
                                        { '$eq': ['$retweet', None] },
                                        '$favorite_count',
                                        '$retweet.favorite_count'
                                    ]
                                },
                                '$quote.favorite_count'
                            ]
                        }
                    },
                    'quote_count': {
                        '$sum': {
                            '$cond': [
                                { '$eq': ['$quote', None] },
                                {
                                    '$cond': [
                                        { '$eq': ['$retweet', None] },
                                        '$quote_count',
                                        '$retweet.quote_count'
                                    ]
                                },
                                '$quote.quote_count'
                            ]
                        }
                    },
                }
            },
            {
                '$addFields': {
                    'engagement': {
                        '$sum': ['$retweet_count', '$reply_count', '$favorite_count', '$quote_count']
                    }
                }
            },
            {
                '$sort': {
                    'engagement': pymongo.DESCENDING
                }
            },
            {
                '$limit': n
            }
        ]

        tweets = list(self.tweets_collection.aggregate(pipeline))
        self.cache['most_engaging_tweets'] = tweets
        return tweets


    
    
    def search_by_username(self, username, n=10):
        """
        Returns the top n users in the database matching the given username.

        Args:
        - username (str): The username to search for.
        - n (int): Number of users to return.

        Returns:
        - list: List of the top n users, each represented as a dictionary.
        """
        if username in self.cache:
            print(f"Retrieving {username} from cache!")
            return self.cache[username]

        query = f"""
            SELECT user_id, name, twitter_join_date, followers_count,
            friends_count, favourites_count, verified
            FROM {self.user_table}
            WHERE name LIKE '%{username}%'
            ORDER BY followers_count DESC, verified DESC
            LIMIT {n}
        """
        self.users_cursor.execute(query)
        results = self.users_cursor.fetchall()

        users = []
        for row in results:
            user = {
                'user_id': row[0],
                'name': row[1],
                'twitter_join_date': row[2],
                'followers_count': row[3],
                'friends_count': row[4],
                'favourites_count': row[5]
                'verified': row[6]
            }
            users.append(user)

        self.cache[username] = users
        return users

# %%
# create a SearchEngine object for MongoDB with cache size of 50 and cache TTL of 10 seconds
search_engine = SearchEngine(db_type='mongodb', cache_size=50, cache_ttl=60)

# %%
users = search_engine.search_by_username("juwelz v")
users
# Out:
#        name                                         text  reply_count  \
# 0  juwelz v  wishing death on people is weirdo behavior.            0
#
#    engagement_score
# 0                 0

# %%
top_tweets = search_engine.most_engaging_tweets()
top_tweets
# Out:
# [{'tweet_id': 1254051230822944770,
#   'user': 1039346340449452033,
#   'name': 'Grace',
#   'date': 'Sat Apr 25 14:14:47 +0000 2020',
#   'text': 'But Joe, what if I WANT to drink bleach? What if I wanted to do that even before the orange man said to inject Lysol into our veins to stop corona? What if?',
#   'retweet': None,
#   'quote': {'tweet_id': 1253751812194070529,
#    'user_id': 939091,
#    'user_name': 'Joe Biden',
#    'quote_count': 32237,
#    'reply_count': 46159,
#    'retweet_count': 263475,
#    'favorite_count': 1280593,
#    'media': {'hashtags': [], 'urls': [], 'mentions': []}},
#   'retweet_count': 263475,
#   'reply_count': 46159,
#   'favorite_count': 1280593,
#   'quote_count': 32237,
#   'engagement': 1622464},
#  {'tweet_id': 1254044290344521728,
#   'user': 863214058845200384,
#   'name': 'Control Roboto 🤖 💚 Cine y Series',
#   'date': 'Sat Apr 25 13:47:12 +0000 2020',
#   'text': 'Esto es terrible, si no los mata el corona, se matan entre ellos con rifles o tomando lavandina.\nDe pedo siguen vivos.',
#   'retweet': None,
#   'quote': {'tweet_id': 1253751812194070529,
#    'user_id': 939091,
#    'user_name': 'Joe Biden',
#    'quote_count': 31948,
#    'reply_count': 45651,
#    'retweet_count': 261022,
#    'favorite_count': 1268245,
#    'media': {'hashtags': [], 'urls': [], 'mentions': []}},
#   'retweet_count': 261022,
#   'reply_count': 45651,
#   'favorite_count': 1268245,
#   'quote_count': 31948,
#   'engagement': 1606866},
#  {'tweet_id': 1254038725207752704,
#   'user': 3105439805,
#   'name': 'Single Mom',
#   'date': 'Sat Apr 25 13:25:05 +0000 2020',
#   'text': 'O corona buraya gelecek.',
#   'retweet': None,
#   'quote': {'tweet_id': 1253751812194070529,
#    'user_id': 939091,
#    'user_name': 'Joe Biden',
#    'quote_count': 31716,
#    'reply_count': 45269,
#    'retweet_count': 259104,
#    'favorite_count': 1258143,
#    'media': {'hashtags': [], 'urls': [], 'mentions': []}},
#   'retweet_count': 259104,
#   'reply_count': 45269,
#   'favorite_count': 1258143,
#   'quote_count': 31716,
#   'engagement': 1594232},
#  {'tweet_id': 1254028187685793797,
#   'user': 45727123,
#   'name': 'diego',
#   'date': 'Sat Apr 25 12:43:13 +0000 2020',
#   'text': 'Enquanto isso nos EUA, o Biden tem que pedir pra não tomarem desinfetante pq o Trump disse que curava o corona',
#   'retweet': None,
#   'quote': {'tweet_id': 1253751812194070529,
#    'user_id': 939091,
#    'user_name': 'Joe Biden',
#    'quote_count': 31291,
#    'reply_count': 44447,
#    'retweet_count': 255239,
#    'favorite_count': 1238840,
#    'media': {'hashtags': [], 'urls': [], 'mentions': []}},
#   'retweet_count': 255239,
#   'reply_count': 44447,
#   'favorite_count': 1238840,
#   'quote_count': 31291,
#   'engagement': 1569817},
#  {'tweet_id': 1249408877554270208,
#   'user': 944115288412442625,
#   'name': 'm',
#   'date': 'Sun Apr 12 18:47:43 +0000 2020',
#   'text': "ALERT‼️‼️‼️\nThe corona virus can be spread through money. If you have any money at home, put on some gloves, put all the money in to a plastic bag and put it outside the front door tonight. I'm collecting all the plastic bags tonight for safety. Think of your health.",
#   'retweet': {'tweet_id': 1235256530728972290,
#    'user_id': 2863558530,
#    'user_name': 'Pre K ❄️',
#    'quote_count': 9755,
#    'reply_count': 3269,
#    'retweet_count': 298538,
#    'favorite_count': 1128502,
#    'created_at': 'Wed Mar 04 17:31:21 +0000 2020',
#    'media': {'hashtags': [],
#     'urls': ['https://t.co/juJjDpFN3I'],
#     'mentions': []}},
#   'quote': None,
#   'retweet_count': 298538,
#   'reply_count': 3269,
#   'favorite_count': 1128502,
#   'quote_count': 9755,
#   'engagement': 1440064},
#  {'tweet_id': 1254038604927643653,
#   'user': 810639585143300096,
#   'name': 'Ethan M',
#   'date': 'Sat Apr 25 13:24:36 +0000 2020',
#   'text': '*corona virus enters my body*\n\nThe 4 Flintstone gummies I ate in 2005: https://t.co/3STfdIQtaT',
#   'retweet': {'tweet_id': 1238264431320215553,
#    'user_id': 1100261477989126145,
#    'user_name': 'gilbert🚀',
#    'quote_count': 6828,
#    'reply_count': 1811,
#    'retweet_count': 237307,
#    'favorite_count': 811062,
#    'created_at': 'Fri Mar 13 00:43:40 +0000 2020',
#    'media': {'hashtags': [], 'urls': [], 'mentions': []}},
#   'quote': None,
#   'retweet_count': 237307,
#   'reply_count': 1811,
#   'favorite_count': 811062,
#   'quote_count': 6828,
#   'engagement': 1057008},
#  {'tweet_id': 1254035181465481217,
#   'user': 796101530382385152,
#   'name': 'ChickenSmugglerMyungsoo',
#   'date': 'Sat Apr 25 13:11:00 +0000 2020',
#   'text': 'When this Corona shit passes we have to promise each other that we’re going to tell our kids that we survived a zombie apocalypse in 2020',
#   'retweet': {'tweet_id': 1240334979701395458,
#    'user_id': 1112592502727548928,
#    'user_name': 'D i l l 🦦',
#    'quote_count': 4442,
#    'reply_count': 1595,
#    'retweet_count': 181584,
#    'favorite_count': 764405,
#    'created_at': 'Wed Mar 18 17:51:18 +0000 2020',
#    'media': {'hashtags': [], 'urls': [], 'mentions': []}},
#   'quote': None,
#   'retweet_count': 181584,
#   'reply_count': 1595,
#   'favorite_count': 764405,
#   'quote_count': 4442,
#   'engagement': 952026},
#  {'tweet_id': 1254037586265411584,
#   'user': 46593203,
#   'name': 'Bloo 🦛 하마',
#   'date': 'Sat Apr 25 13:20:34 +0000 2020',
#   'text': 'When this Corona shit passes we have to promise each other that we’re going to tell our kids that we survived a zombie apocalypse in 2020',
#   'retweet': {'tweet_id': 1240334979701395458,
#    'user_id': 1112592502727548928,
#    'user_name': 'D i l l 🦦',
#    'quote_count': 4442,
#    'reply_count': 1595,
#    'retweet_count': 181584,
#    'favorite_count': 764405,
#    'created_at': 'Wed Mar 18 17:51:18 +0000 2020',
#    'media': {'hashtags': [], 'urls': [], 'mentions': []}},
#   'quote': None,
#   'retweet_count': 181584,
#   'reply_count': 1595,
#   'favorite_count': 764405,
#   'quote_count': 4442,
#   'engagement': 952026},
#  {'tweet_id': 1254047697251827712,
#   'user': 1168550880,
#   'name': 'annimeaculpa',
#   'date': 'Sat Apr 25 14:00:44 +0000 2020',
#   'text': 'No words! 🤣😂🤣😂😂🤣🤣😂',
#   'retweet': {'tweet_id': 1221856224712495104,
#    'user_id': 762190964404412416,
#    'user_name': 'night owl',
#    'quote_count': 13732,
#    'reply_count': 3294,
#    'retweet_count': 190463,
#    'favorite_count': 672069,
#    'created_at': 'Mon Jan 27 18:03:19 +0000 2020',
#    'media': {'hashtags': [],
#     'urls': ['https://t.co/DZTqwGdYLv'],
#     'mentions': []}},
#   'quote': {'tweet_id': 1221856224712495104,
#    'user_id': 762190964404412416,
#    'user_name': 'night owl',
#    'quote_count': 13732,
#    'reply_count': 3294,
#    'retweet_count': 190463,
#    'favorite_count': 672069,
#    'media': {'hashtags': [],
#     'urls': ['https://t.co/DZTqwGdYLv'],
#     'mentions': []}},
#   'retweet_count': 190463,
#   'reply_count': 3294,
#   'favorite_count': 672069,
#   'quote_count': 13732,
#   'engagement': 879558},
#  {'tweet_id': 1249407754286051328,
#   'user': 183036721,
#   'name': 'John Dalton',
#   'date': 'Sun Apr 12 18:43:16 +0000 2020',
#   'text': 'If I gave you 100 skittles and told you 3 of them could kill you.... I’m sure you would avoid the fucking skittles',
#   'retweet': {'tweet_id': 1238452293655310338,
#    'user_id': 236625110,
#    'user_name': 'WUD?',
#    'quote_count': 13005,
#    'reply_count': 6150,
#    'retweet_count': 160253,
#    'favorite_count': 685153,
#    'created_at': 'Fri Mar 13 13:10:10 +0000 2020',
#    'media': {'hashtags': [], 'urls': [], 'mentions': []}},
#   'quote': {'tweet_id': 1238452293655310338,
#    'user_id': 236625110,
#    'user_name': 'WUD?',
#    'quote_count': 13005,
#    'reply_count': 6150,
#    'retweet_count': 160253,
#    'favorite_count': 685153,
#    'media': {'hashtags': [], 'urls': [], 'mentions': []}},
#   'retweet_count': 160253,
#   'reply_count': 6150,
#   'favorite_count': 685153,
#   'quote_count': 13005,
#   'engagement': 864561}]
