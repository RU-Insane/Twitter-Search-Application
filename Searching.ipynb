# %%
import time
import pymongo
import psycopg2
import pandas as pd
from cache import SearchCache

# %%
class SearchEngine:
    def __init__(self, cache_size=100, cache_ttl=3600):
        """
        Initializes a SearchEngine object with a specified database type and cache settings.

        Args:
        - cache_size (int): Maximum number of items to store in cache
        - cache_ttl (int): Time-to-live (in seconds) for cached items
        """
        # initialize a cache object for the search engine using the SearchCache class
        self.cache = SearchCache(cache_size, cache_ttl)
        self.db_client = pymongo.MongoClient('mongodb+srv://twitter_user:dbms@cluster0.wkyhu.mongodb.net/?retryWrites=true&w=majority')
        self.tweets_collection = self.db_client['twitter_db']['tweets_data']
        self.db_conn = psycopg2.connect(database="postgres", user="postgres", password="kueen", host="localhost")
        self.users_cursor = self.db_conn.cursor()
        self.user_table = 'twitter_users_partitioned'

    
    def most_engaging_tweets(self, n=10):
        """
        Returns the most engaging n tweets in the database, where engagement is defined as the sum of retweet
        count, reply count, quote count, and favorite count.

        Args:
        - n (int): Number of tweets to return.

        Returns:
        - list: List of the top n tweets, each represented as a dictionary.
        """
        if 'most_engaging_tweets' in self.cache:
            print("Retrieving 'most engaging tweets' from cache!")
            return self.cache['most_engaging_tweets']

        pipeline = [
            {
                '$project': {
                    '_id': 0,
                    'tweet_id': 1,
                    'user': 1,
                    'name': 1,
                    'date': 1,
                    'text': 1,
                    'retweet': {
                        '$cond': {
                            'if': { '$eq': ['$is_retweet', True] },
                            'then': '$retweet',
                            'else': None
                        }
                    },
                    'quote': {
                        '$cond': {
                            'if': { '$eq': ['$is_quote', True] },
                            'then': '$quote',
                            'else': None
                        }
                    },
                    'retweet_count': {
                        '$sum': {
                            '$cond': [
                                { '$eq': ['$quote', None] },
                                {
                                    '$cond': [
                                        { '$eq': ['$retweet', None] },
                                        '$retweet_count',
                                        '$retweet.retweet_count'
                                    ]
                                },
                                '$quote.retweet_count'
                            ]
                        }
                    },
                    'reply_count': {
                        '$sum': {
                            '$cond': [
                                { '$eq': ['$quote', None] },
                                {
                                    '$cond': [
                                        { '$eq': ['$retweet', None] },
                                        '$reply_count',
                                        '$retweet.reply_count'
                                    ]
                                },
                                '$quote.reply_count'
                            ]
                        }
                    },
                    'favorite_count': {
                        '$sum': {
                            '$cond': [
                                { '$eq': ['$quote', None] },
                                {
                                    '$cond': [
                                        { '$eq': ['$retweet', None] },
                                        '$favorite_count',
                                        '$retweet.favorite_count'
                                    ]
                                },
                                '$quote.favorite_count'
                            ]
                        }
                    },
                    'quote_count': {
                        '$sum': {
                            '$cond': [
                                { '$eq': ['$quote', None] },
                                {
                                    '$cond': [
                                        { '$eq': ['$retweet', None] },
                                        '$quote_count',
                                        '$retweet.quote_count'
                                    ]
                                },
                                '$quote.quote_count'
                            ]
                        }
                    },
                }
            },
            {
                '$addFields': {
                    'engagement': {
                        '$add': [
                            {'$multiply': ['$retweet_count', 0.2]},
                            {'$multiply': ['$favorite_count', 0.2]},
                            {'$multiply': ['$reply_count', 0.3]},
                            {'$multiply': ['$quote_count', 0.3]}
                        ]
                    }
                }
            },
            {
                '$sort': {
                    'engagement': pymongo.DESCENDING,
                    'date': pymongo.DESCENDING
                }
            },
            {
                '$limit': n
            }
        ]

        tweets = list(self.tweets_collection.aggregate(pipeline))
        self.cache['most_engaging_tweets'] = tweets
        return tweets

    
    def most_popular_hashtags(self, n=10):
        """
        Returns the n most popular hashtags in the database.

        Args:
        - n (int): Number of hashtags to return.

        Returns:
        - list: List of the top n hashtags, each represented as a dictionary.
        """
        if 'most_popular_hashtags' in self.cache:
            print("Retrieving 'most popular hashtags' from cache!")
            return self.cache['most_popular_hashtags']

        pipeline = [
            {
                '$match': {
                    '$or': [
                        {'media.hashtags': {'$exists': True}},
                        {'retweet.media.hashtags': {'$exists': True}},
                        {'quote.media.hashtags': {'$exists': True}},
                    ]
                }
            },
            {
                '$project': {
                    '_id': 0,
                    'hashtags': {
                        '$concatArrays': [
                            {'$ifNull': ['$media.hashtags', []]},
                            {'$ifNull': ['$retweet.media.hashtags', []]},
                            {'$ifNull': ['$quote.media.hashtags', []]},
                        ]
                    }
                }
            },
            {
                '$unwind': '$hashtags'
            },
            {
                '$group': {
                    '_id': '$hashtags',
                    'count': {'$sum': 1}
                }
            },
            {
                '$sort': {
                    'count': pymongo.DESCENDING,
                    'date': pymongo.DESCENDING
                }
            },
            {
                '$limit': n
            }
        ]

        hashtags = list(self.tweets_collection.aggregate(pipeline))
        hashtags = [{x["_id"]: x["count"]} for x in hashtags]
        self.cache['most_popular_hashtags'] = hashtags
        return hashtags


    def search_by_username(self, username, n=10):
        """
        Returns the top n users in the database matching the given username.

        Args:
        - username (str): The username to search for.
        - n (int): Number of users to return.

        Returns:
        - list: List of the top n users, each represented as a dictionary.
        """
        if username in self.cache:
            print(f"Retrieving {username} from cache!")
            return self.cache[username]

        query = f"""
            SELECT user_id, name, twitter_join_date, location, 
            verified, followers_count, friends_count, favourites_count
            FROM {self.user_table}
            WHERE name LIKE '%{username}%'
            AND (name, date, followers_count) IN (
                SELECT name, MAX(date), MAX(followers_count)
                FROM {self.user_table}
                WHERE name LIKE '%{username}%'
                GROUP BY name, user_id
            )
            ORDER BY followers_count DESC, verified DESC
            LIMIT {n}
        """

        self.users_cursor.execute(query)
        results = self.users_cursor.fetchall()

        users = []
        for row in results:
            user = {
                'user_id': row[0],
                'name': row[1],
                'twitter_join_date': row[2],
                'location': row[3],
                'verified': row[4],
                'followers_count': row[5],
                'friends_count': row[6],
                'favourites_count': row[7],
            }
            users.append(user)

        users = pd.DataFrame(users)
        self.cache[username] = users
        return users
    
    def search_by_word(self, word, n=10):
        """
        Returns the top n tweets in the database that contain the given word.

        Args:
        - word (str): The word to search for.
        - n (int): Number of tweets to return.

        Returns:
        - list: List of the top n tweets, each represented as a dictionary.
        """
        if word in self.cache:
            print(f"Retrieving {word} from cache!")
            return self.cache[word]

        pipeline = [
            {
                '$match': {
                    '$text': {'$search': word}
                }
            },
            {
                '$project': {
                    '_id': 0,
                    'tweet_id': 1,
                    'user': 1,
                    'name': 1,
                    'date': 1,
                    'text': 1,
                    'retweet': {
                        '$cond': {
                            'if': { '$eq': ['$is_retweet', True] },
                            'then': '$retweet',
                            'else': None
                        }
                    },
                    'quote': {
                        '$cond': {
                            'if': { '$eq': ['$is_quote', True] },
                            'then': '$quote',
                            'else': None
                        }
                    },
                    'retweet_count': {
                        '$sum': {
                            '$cond': [
                                { '$eq': ['$retweet', None] },
                                '$retweet_count',
                                '$retweet.retweet_count'
                            ]
                        }
                    },
                    'reply_count': {
                        '$sum': {
                            '$cond': [
                                { '$eq': ['$quote', None] },
                                {
                                    '$cond': [
                                        { '$eq': ['$retweet', None] },
                                        '$reply_count',
                                        '$retweet.reply_count'
                                    ]
                                },
                                '$quote.reply_count'
                            ]
                        }
                    },
                    'favorite_count': {
                        '$sum': {
                            '$cond': [
                                { '$eq': ['$retweet', None] },
                                '$favorite_count',
                                '$retweet.favorite_count'
                            ]
                        }
                    },
                    'quote_count': {
                        '$max': {
                            '$cond': [
                                { '$eq': ['$quote', None] },
                                '$quote_count',
                                '$quote.quote_count'
                            ]
                        }
                    },
                },
            },
            {
                '$addFields': {
                    'engagement': {
                        '$toInt': {
                            '$add': [
                                {'$multiply': ['$retweet_count', 0.2]},
                                {'$multiply': ['$favorite_count', 0.2]},
                                {'$multiply': ['$reply_count', 0.3]},
                                {'$multiply': ['$quote_count', 0.3]}
                            ]
                        }
                    }
                }
            },
            {
                '$sort': {
                    'engagement': pymongo.DESCENDING,
                    'date': pymongo.DESCENDING
                }
            },
            {
                '$limit': n
            }
        ]

        tweets = list(self.tweets_collection.aggregate(pipeline))
        self.cache[word] = tweets
        return tweets

# %%
# create a SearchEngine object with cache size of 50 and cache TTL of 10 seconds
search_engine = SearchEngine(cache_size=50, cache_ttl=60)

# %%
top_tweets = search_engine.most_engaging_tweets()
top_tweets
# Out:
# [{'tweet_id': 1254051230822944770,
#   'user': 1039346340449452033,
#   'name': 'Grace',
#   'date': 'Sat Apr 25 14:14:47 +0000 2020',
#   'text': 'But Joe, what if I WANT to drink bleach? What if I wanted to do that even before the orange man said to inject Lysol into our veins to stop corona? What if?',
#   'retweet': None,
#   'quote': {'tweet_id': 1253751812194070529,
#    'user_id': 939091,
#    'user_name': 'Joe Biden',
#    'quote_count': 32237,
#    'reply_count': 46159,
#    'retweet_count': 263475,
#    'favorite_count': 1280593,
#    'media': {'hashtags': [], 'urls': [], 'mentions': []}},
#   'retweet_count': 263475,
#   'reply_count': 46159,
#   'favorite_count': 1280593,
#   'quote_count': 32237,
#   'engagement': 457167.99999999994},
#  {'tweet_id': 1254044290344521728,
#   'user': 863214058845200384,
#   'name': 'Control Roboto 🤖 💚 Cine y Series',
#   'date': 'Sat Apr 25 13:47:12 +0000 2020',
#   'text': 'Esto es terrible, si no los mata el corona, se matan entre ellos con rifles o tomando lavandina.\nDe pedo siguen vivos.',
#   'retweet': None,
#   'quote': {'tweet_id': 1253751812194070529,
#    'user_id': 939091,
#    'user_name': 'Joe Biden',
#    'quote_count': 31948,
#    'reply_count': 45651,
#    'retweet_count': 261022,
#    'favorite_count': 1268245,
#    'media': {'hashtags': [], 'urls': [], 'mentions': []}},
#   'retweet_count': 261022,
#   'reply_count': 45651,
#   'favorite_count': 1268245,
#   'quote_count': 31948,
#   'engagement': 452762.8},
#  {'tweet_id': 1254038725207752704,
#   'user': 3105439805,
#   'name': 'Single Mom',
#   'date': 'Sat Apr 25 13:25:05 +0000 2020',
#   'text': 'O corona buraya gelecek.',
#   'retweet': None,
#   'quote': {'tweet_id': 1253751812194070529,
#    'user_id': 939091,
#    'user_name': 'Joe Biden',
#    'quote_count': 31716,
#    'reply_count': 45269,
#    'retweet_count': 259104,
#    'favorite_count': 1258143,
#    'media': {'hashtags': [], 'urls': [], 'mentions': []}},
#   'retweet_count': 259104,
#   'reply_count': 45269,
#   'favorite_count': 1258143,
#   'quote_count': 31716,
#   'engagement': 449187.6},
#  {'tweet_id': 1254028187685793797,
#   'user': 45727123,
#   'name': 'diego',
#   'date': 'Sat Apr 25 12:43:13 +0000 2020',
#   'text': 'Enquanto isso nos EUA, o Biden tem que pedir pra não tomarem desinfetante pq o Trump disse que curava o corona',
#   'retweet': None,
#   'quote': {'tweet_id': 1253751812194070529,
#    'user_id': 939091,
#    'user_name': 'Joe Biden',
#    'quote_count': 31291,
#    'reply_count': 44447,
#    'retweet_count': 255239,
#    'favorite_count': 1238840,
#    'media': {'hashtags': [], 'urls': [], 'mentions': []}},
#   'retweet_count': 255239,
#   'reply_count': 44447,
#   'favorite_count': 1238840,
#   'quote_count': 31291,
#   'engagement': 442292.1},
#  {'tweet_id': 1249408877554270208,
#   'user': 944115288412442625,
#   'name': 'm',
#   'date': 'Sun Apr 12 18:47:43 +0000 2020',
#   'text': "ALERT‼️‼️‼️\nThe corona virus can be spread through money. If you have any money at home, put on some gloves, put all the money in to a plastic bag and put it outside the front door tonight. I'm collecting all the plastic bags tonight for safety. Think of your health.",
#   'retweet': {'tweet_id': 1235256530728972290,
#    'user_id': 2863558530,
#    'user_name': 'Pre K ❄️',
#    'quote_count': 9755,
#    'reply_count': 3269,
#    'retweet_count': 298538,
#    'favorite_count': 1128502,
#    'created_at': 'Wed Mar 04 17:31:21 +0000 2020',
#    'media': {'hashtags': [],
#     'urls': ['https://t.co/juJjDpFN3I'],
#     'mentions': []}},
#   'quote': None,
#   'retweet_count': 298538,
#   'reply_count': 3269,
#   'favorite_count': 1128502,
#   'quote_count': 9755,
#   'engagement': 401189.89999999997},
#  {'tweet_id': 1254038604927643653,
#   'user': 810639585143300096,
#   'name': 'Ethan M',
#   'date': 'Sat Apr 25 13:24:36 +0000 2020',
#   'text': '*corona virus enters my body*\n\nThe 4 Flintstone gummies I ate in 2005: https://t.co/3STfdIQtaT',
#   'retweet': {'tweet_id': 1238264431320215553,
#    'user_id': 1100261477989126145,
#    'user_name': 'gilbert🚀',
#    'quote_count': 6828,
#    'reply_count': 1811,
#    'retweet_count': 237307,
#    'favorite_count': 811062,
#    'created_at': 'Fri Mar 13 00:43:40 +0000 2020',
#    'media': {'hashtags': [], 'urls': [], 'mentions': []}},
#   'quote': None,
#   'retweet_count': 237307,
#   'reply_count': 1811,
#   'favorite_count': 811062,
#   'quote_count': 6828,
#   'engagement': 292688.89999999997},
#  {'tweet_id': 1254037586265411584,
#   'user': 46593203,
#   'name': 'Bloo 🦛 하마',
#   'date': 'Sat Apr 25 13:20:34 +0000 2020',
#   'text': 'When this Corona shit passes we have to promise each other that we’re going to tell our kids that we survived a zombie apocalypse in 2020',
#   'retweet': {'tweet_id': 1240334979701395458,
#    'user_id': 1112592502727548928,
#    'user_name': 'D i l l 🦦',
#    'quote_count': 4442,
#    'reply_count': 1595,
#    'retweet_count': 181584,
#    'favorite_count': 764405,
#    'created_at': 'Wed Mar 18 17:51:18 +0000 2020',
#    'media': {'hashtags': [], 'urls': [], 'mentions': []}},
#   'quote': None,
#   'retweet_count': 181584,
#   'reply_count': 1595,
#   'favorite_count': 764405,
#   'quote_count': 4442,
#   'engagement': 267005.2},
#  {'tweet_id': 1254035181465481217,
#   'user': 796101530382385152,
#   'name': 'ChickenSmugglerMyungsoo',
#   'date': 'Sat Apr 25 13:11:00 +0000 2020',
#   'text': 'When this Corona shit passes we have to promise each other that we’re going to tell our kids that we survived a zombie apocalypse in 2020',
#   'retweet': {'tweet_id': 1240334979701395458,
#    'user_id': 1112592502727548928,
#    'user_name': 'D i l l 🦦',
#    'quote_count': 4442,
#    'reply_count': 1595,
#    'retweet_count': 181584,
#    'favorite_count': 764405,
#    'created_at': 'Wed Mar 18 17:51:18 +0000 2020',
#    'media': {'hashtags': [], 'urls': [], 'mentions': []}},
#   'quote': None,
#   'retweet_count': 181584,
#   'reply_count': 1595,
#   'favorite_count': 764405,
#   'quote_count': 4442,
#   'engagement': 267005.2},
#  {'tweet_id': 1254047697251827712,
#   'user': 1168550880,
#   'name': 'annimeaculpa',
#   'date': 'Sat Apr 25 14:00:44 +0000 2020',
#   'text': 'No words! 🤣😂🤣😂😂🤣🤣😂',
#   'retweet': {'tweet_id': 1221856224712495104,
#    'user_id': 762190964404412416,
#    'user_name': 'night owl',
#    'quote_count': 13732,
#    'reply_count': 3294,
#    'retweet_count': 190463,
#    'favorite_count': 672069,
#    'created_at': 'Mon Jan 27 18:03:19 +0000 2020',
#    'media': {'hashtags': [],
#     'urls': ['https://t.co/DZTqwGdYLv'],
#     'mentions': []}},
#   'quote': {'tweet_id': 1221856224712495104,
#    'user_id': 762190964404412416,
#    'user_name': 'night owl',
#    'quote_count': 13732,
#    'reply_count': 3294,
#    'retweet_count': 190463,
#    'favorite_count': 672069,
#    'media': {'hashtags': [],
#     'urls': ['https://t.co/DZTqwGdYLv'],
#     'mentions': []}},
#   'retweet_count': 190463,
#   'reply_count': 3294,
#   'favorite_count': 672069,
#   'quote_count': 13732,
#   'engagement': 243447.9},
#  {'tweet_id': 1249407754286051328,
#   'user': 183036721,
#   'name': 'John Dalton',
#   'date': 'Sun Apr 12 18:43:16 +0000 2020',
#   'text': 'If I gave you 100 skittles and told you 3 of them could kill you.... I’m sure you would avoid the fucking skittles',
#   'retweet': {'tweet_id': 1238452293655310338,
#    'user_id': 236625110,
#    'user_name': 'WUD?',
#    'quote_count': 13005,
#    'reply_count': 6150,
#    'retweet_count': 160253,
#    'favorite_count': 685153,
#    'created_at': 'Fri Mar 13 13:10:10 +0000 2020',
#    'media': {'hashtags': [], 'urls': [], 'mentions': []}},
#   'quote': {'tweet_id': 1238452293655310338,
#    'user_id': 236625110,
#    'user_name': 'WUD?',
#    'quote_count': 13005,
#    'reply_count': 6150,
#    'retweet_count': 160253,
#    'favorite_count': 685153,
#    'media': {'hashtags': [], 'urls': [], 'mentions': []}},
#   'retweet_count': 160253,
#   'reply_count': 6150,
#   'favorite_count': 685153,
#   'quote_count': 13005,
#   'engagement': 242042.5}]

# %%
top_hashtags = search_engine.most_popular_hashtags()
top_hashtags
# Out:
# [{'Corona': 9800},
#  {'Mattarella': 3406},
#  {'25Aprile': 3371},
#  {'corona': 3263},
#  {'AltaredellaPatria': 1829},
#  {'COVID19': 1722},
#  {'PideAlmayaDiyeÇıkıp': 1599},
#  {'Liberazione': 1573},
#  {'Covid_19': 1545},
#  {'coronavirus': 1160}]

# %%
users = search_engine.search_by_username("Sözcü")
users
# Out:
#       user_id           name twitter_join_date           location  verified  \
# 0   218078497          Sözcü        2010-11-21           İstanbul      True
# 1  3142919739    Sözcü Dünya        2015-04-07  İstanbul, Türkiye     False
# 2  3501964461  Sözcü Ekonomi        2015-08-31               None     False
#
#    followers_count  friends_count  favourites_count
# 0          2398838             28                 0
# 1            39909             11                 0
# 2            23393             13                 0

# %%
tweets = search_engine.search_by_word("covid")
tweets
# Out:
# [{'tweet_id': 1254038666147770374,
#   'user': 1452204385,
#   'name': 'DelilerTag3',
#   'date': 'Sat Apr 25 13:24:51 +0000 2020',
#   'text': 'Günlük iyileşen sayısı günlük vaka sayısını çok şükür geride bıraktı..\nİyi günler yakındır..\n#PideAlmayaDiyeCıkıp heryere gidersiniz artık..\n#Covid_19 #COVID19 #coronavirus #Corona #COVID',
#   'retweet': {'tweet_id': 1253717449746374657,
#    'user_id': 1016198241417822208,
#    'user_name': 'Dr. Fahrettin Koca',
#    'quote_count': 3416,
#    'reply_count': 4456,
#    'retweet_count': 25062,
#    'favorite_count': 188607,
#    'created_at': 'Fri Apr 24 16:08:27 +0000 2020',
#    'media': {'hashtags': [],
#     'urls': ['https://t.co/Av6p0M43ov'],
#     'mentions': []}},
#   'quote': {'tweet_id': 1253717449746374657,
#    'user_id': 1016198241417822208,
#    'user_name': 'Dr. Fahrettin Koca',
#    'quote_count': 3416,
#    'reply_count': 4456,
#    'retweet_count': 25062,
#    'favorite_count': 188607,
#    'media': {'hashtags': [],
#     'urls': ['https://t.co/Av6p0M43ov'],
#     'mentions': []}},
#   'retweet_count': 25062,
#   'reply_count': 4456,
#   'favorite_count': 188607,
#   'quote_count': 3416,
#   'engagement': 63614},
#  {'tweet_id': 1254039144386326529,
#   'user': 1197168671212240896,
#   'name': 'Abu Hamzah Ar Rizal',
#   'date': 'Sat Apr 25 13:26:45 +0000 2020',
#   'text': 'Gua resah dengan kondisi saat ini, gua pengen speak up sebagai pasien suspect Covid-19. Gua akan cerita tentang pengalaman gua sebagai pasien di salah satu RS Rujukan di Jakarta dan keresahan gua terkait corona.\n\na thread!!',
#   'retweet': {'tweet_id': 1239499987785904128,
#    'user_id': 525117186,
#    'user_name': 'Fachri Muchtar',
#    'quote_count': 3582,
#    'reply_count': 2053,
#    'retweet_count': 69562,
#    'favorite_count': 108791,
#    'created_at': 'Mon Mar 16 10:33:20 +0000 2020',
#    'media': {'hashtags': [],
#     'urls': ['https://t.co/qvvxEvYpZ6'],
#     'mentions': []}},
#   'quote': None,
#   'retweet_count': 69562,
#   'reply_count': 2053,
#   'favorite_count': 108791,
#   'quote_count': 0,
#   'engagement': 47165},
#  {'tweet_id': 1254043238698086400,
#   'user': 123827118,
#   'name': 'eatp',
#   'date': 'Sat Apr 25 13:43:01 +0000 2020',
#   'text': 'Dengan dampak dari virus corona (Covid-19) dan dipenuhi dengan ketakutan untuk masa depan yang tidak pasti disertai kebingungan dan kesulitan besar.',
#   'retweet': {'tweet_id': 1241702480183824386,
#    'user_id': 125603760,
#    'user_name': 'Siwon Choi',
#    'quote_count': 3594,
#    'reply_count': 4540,
#    'retweet_count': 26796,
#    'favorite_count': 93806,
#    'created_at': 'Sun Mar 22 12:25:15 +0000 2020',
#    'media': {'hashtags': [],
#     'urls': ['https://t.co/E31Ky8GkSz'],
#     'mentions': []}},
#   'quote': None,
#   'retweet_count': 26796,
#   'reply_count': 4540,
#   'favorite_count': 93806,
#   'quote_count': 0,
#   'engagement': 34863},
#  {'tweet_id': 1254048788924305408,
#   'user': 2426435516,
#   'name': 'WE LOVE U SK :))',
#   'date': 'Sat Apr 25 14:05:05 +0000 2020',
#   'text': 'Thank you for your kind words of appreciation @BeingSalmanKhan Ji. This is a small extension of “Being Human", a foot forward in helping people in these challenging times of COVID-19. I am confident that we will soon make Maharashtra &amp; subsequently the whole of India corona-free. https://t.co/qRSBuUzoPy',
#   'retweet': {'tweet_id': 1252905951390097409,
#    'user_id': 132385468,
#    'user_name': 'Salman Khan',
#    'quote_count': 224,
#    'reply_count': 2268,
#    'retweet_count': 4847,
#    'favorite_count': 52969,
#    'created_at': 'Wed Apr 22 10:23:51 +0000 2020',
#    'media': {'hashtags': [], 'urls': [], 'mentions': ['ruturajdyp']}},
#   'quote': {'tweet_id': 1252905951390097409,
#    'user_id': 132385468,
#    'user_name': 'Salman Khan',
#    'quote_count': 224,
#    'reply_count': 2268,
#    'retweet_count': 4847,
#    'favorite_count': 52969,
#    'media': {'hashtags': [], 'urls': [], 'mentions': ['ruturajdyp']}},
#   'retweet_count': 4847,
#   'reply_count': 2268,
#   'favorite_count': 52969,
#   'quote_count': 224,
#   'engagement': 17585},
#  {'tweet_id': 1254031462522687488,
#   'user': 907127093506457600,
#   'name': 'Being Tublight',
#   'date': 'Sat Apr 25 12:56:14 +0000 2020',
#   'text': 'Thank you for your kind words of appreciation @BeingSalmanKhan Ji. This is a small extension of “Being Human", a foot forward in helping people in these challenging times of COVID-19. I am confident that we will soon make Maharashtra &amp; subsequently the whole of India corona-free. https://t.co/qRSBuUzoPy',
#   'retweet': {'tweet_id': 1252905951390097409,
#    'user_id': 132385468,
#    'user_name': 'Salman Khan',
#    'quote_count': 224,
#    'reply_count': 2267,
#    'retweet_count': 4841,
#    'favorite_count': 52879,
#    'created_at': 'Wed Apr 22 10:23:51 +0000 2020',
#    'media': {'hashtags': [], 'urls': [], 'mentions': ['ruturajdyp']}},
#   'quote': {'tweet_id': 1252905951390097409,
#    'user_id': 132385468,
#    'user_name': 'Salman Khan',
#    'quote_count': 224,
#    'reply_count': 2267,
#    'retweet_count': 4841,
#    'favorite_count': 52879,
#    'media': {'hashtags': [], 'urls': [], 'mentions': ['ruturajdyp']}},
#   'retweet_count': 4841,
#   'reply_count': 2267,
#   'favorite_count': 52879,
#   'quote_count': 224,
#   'engagement': 17556},
#  {'tweet_id': 1254031446760546304,
#   'user': 1243738897198137344,
#   'name': '拡散仙人@相互フォロー目標5000人！',
#   'date': 'Sat Apr 25 12:56:10 +0000 2020',
#   'text': 'Thank you for your kind words of appreciation @BeingSalmanKhan Ji. This is a small extension of “Being Human", a foot forward in helping people in these challenging times of COVID-19. I am confident that we will soon make Maharashtra &amp; subsequently the whole of India corona-free.',
#   'retweet': {'tweet_id': 1252905951390097409,
#    'user_id': 132385468,
#    'user_name': 'Salman Khan',
#    'quote_count': 224,
#    'reply_count': 2267,
#    'retweet_count': 4841,
#    'favorite_count': 52879,
#    'created_at': 'Wed Apr 22 10:23:51 +0000 2020',
#    'media': {'hashtags': [], 'urls': [], 'mentions': ['ruturajdyp']}},
#   'quote': {'tweet_id': 1252905951390097409,
#    'user_id': 132385468,
#    'user_name': 'Salman Khan',
#    'quote_count': 224,
#    'reply_count': 2267,
#    'retweet_count': 4841,
#    'favorite_count': 52879,
#    'media': {'hashtags': [], 'urls': [], 'mentions': ['ruturajdyp']}},
#   'retweet_count': 4841,
#   'reply_count': 2267,
#   'favorite_count': 52879,
#   'quote_count': 224,
#   'engagement': 17556},
#  {'tweet_id': 1254049763470835712,
#   'user': 979415633686384640,
#   'name': 'j e n n y',
#   'date': 'Sat Apr 25 14:08:57 +0000 2020',
#   'text': 'Israel is shutting down COVID-19 Clinics in PALESTINE and THEY ARRESTED THE STAFF. Palestinians don’t even have the RIGHT TO GET TESTED FOR CORONA DURING A PANDEMIC! I’m so tired of seeing my peoples BASIC HUMAN RIGHTS CONSTANTLY being violated.',
#   'retweet': {'tweet_id': 1250490022983110656,
#    'user_id': 3048484490,
#    'user_name': 'Girl 1n Spacê',
#    'quote_count': 445,
#    'reply_count': 95,
#    'retweet_count': 27394,
#    'favorite_count': 38302,
#    'created_at': 'Wed Apr 15 18:23:49 +0000 2020',
#    'media': {'hashtags': [],
#     'urls': ['https://t.co/J7v4CIpVRC'],
#     'mentions': []}},
#   'quote': None,
#   'retweet_count': 27394,
#   'reply_count': 95,
#   'favorite_count': 38302,
#   'quote_count': 0,
#   'engagement': 16997},
#  {'tweet_id': 1254032285264904194,
#   'user': 1038609722973114368,
#   'name': 'ASHISH JI RAJPUT🇮🇳🇮🇳',
#   'date': 'Sat Apr 25 12:59:30 +0000 2020',
#   'text': 'Can you see the link?\n\nLooks like people have closed ranks to uproot the COVID-19 menace. #JantaCurfew',
#   'retweet': {'tweet_id': 1241572251553554433,
#    'user_id': 1042075896520364037,
#    'user_name': 'Mike Hesson',
#    'quote_count': 415,
#    'reply_count': 550,
#    'retweet_count': 9113,
#    'favorite_count': 44672,
#    'created_at': 'Sun Mar 22 03:47:46 +0000 2020',
#    'media': {'hashtags': [],
#     'urls': ['https://t.co/pA6O0UQlMJ'],
#     'mentions': []}},
#   'quote': {'tweet_id': 1241572251553554433,
#    'user_id': 1042075896520364037,
#    'user_name': 'Mike Hesson',
#    'quote_count': 415,
#    'reply_count': 550,
#    'retweet_count': 9113,
#    'favorite_count': 44672,
#    'media': {'hashtags': [],
#     'urls': ['https://t.co/pA6O0UQlMJ'],
#     'mentions': []}},
#   'retweet_count': 9113,
#   'reply_count': 550,
#   'favorite_count': 44672,
#   'quote_count': 415,
#   'engagement': 15472},
#  {'tweet_id': 1254058357046026240,
#   'user': 2571164752,
#   'name': 'CoraBlimey#NHS#SOS💜',
#   'date': 'Sat Apr 25 14:43:06 +0000 2020',
#   'text': '#COVID #capitalism',
#   'retweet': {'tweet_id': 1239236920011603969,
#    'user_id': 78768913,
#    'user_name': 'Richard D. Wolff',
#    'quote_count': 378,
#    'reply_count': 398,
#    'retweet_count': 9599,
#    'favorite_count': 33041,
#    'created_at': 'Sun Mar 15 17:08:00 +0000 2020',
#    'media': {'hashtags': [],
#     'urls': ['https://t.co/7a6SnP8w5d'],
#     'mentions': []}},
#   'quote': {'tweet_id': 1239236920011603969,
#    'user_id': 78768913,
#    'user_name': 'Richard D. Wolff',
#    'quote_count': 378,
#    'reply_count': 398,
#    'retweet_count': 9599,
#    'favorite_count': 33041,
#    'media': {'hashtags': [],
#     'urls': ['https://t.co/7a6SnP8w5d'],
#     'mentions': []}},
#   'retweet_count': 9599,
#   'reply_count': 398,
#   'favorite_count': 33041,
#   'quote_count': 378,
#   'engagement': 12027},
#  {'tweet_id': 1249403774151659521,
#   'user': 3294456317,
#   'name': 'Wiltac',
#   'date': 'Sun Apr 12 18:27:27 +0000 2020',
#   'text': 'In this clip, Trump:\n1. Denies WHO\'s coronavirus death rate based on “hunch"\n2. Calls coronavirus "corona flu"\n3. Suggests it\'s fine for people w/ Covid-19 to go to work\n4. Compares coronavirus to "the regular flu," indicating he doesn\'t get the difference https://t.co/uC9c03zX31',
#   'retweet': {'tweet_id': 1235411751950221312,
#    'user_id': 288277167,
#    'user_name': 'Aaron Rupar',
#    'quote_count': 5896,
#    'reply_count': 3362,
#    'retweet_count': 13482,
#    'favorite_count': 25064,
#    'created_at': 'Thu Mar 05 03:48:09 +0000 2020',
#    'media': {'hashtags': [],
#     'urls': ['https://t.co/mkSwCySBr0'],
#     'mentions': []}},
#   'quote': None,
#   'retweet_count': 13482,
#   'reply_count': 3362,
#   'favorite_count': 25064,
#   'quote_count': 0,
#   'engagement': 11224}]
